# %%
import pandas as pd

# %%
a={
     "Emp_ID" : [1,2,3,4,5,6,7,8],
     "Name" : ['sam','rahul','gaurav','aniket','anjali','ria','muskan','shivangi'],
     "Department" : ['it','hr','sales','it','it','sales','hr','hr'],
     "Salary" : [25000,30000,35000,30000,30000,35000,30000,40000],
     "Working hours" : [8,9,8,9,7,6,7,8]
}
type(a)
df=pd.DataFrame(a)

# %%
df
# Out:
#    Emp_ID      Name Department  Salary  Working hours
# 0       1       sam         it   25000              8
# 1       2     rahul         hr   30000              9
# 2       3    gaurav      sales   35000              8
# 3       4    aniket         it   30000              9
# 4       5    anjali         it   30000              7
# 5       6       ria      sales   35000              6
# 6       7    muskan         hr   30000              7
# 7       8  shivangi         hr   40000              8

# %%
# how to check top 5 data from database
df.head(5)
# Out:
#    Emp_ID    Name Department  Salary  Working hours
# 0       1     sam         it   25000              8
# 1       2   rahul         hr   30000              9
# 2       3  gaurav      sales   35000              8
# 3       4  aniket         it   30000              9
# 4       5  anjali         it   30000              7

# %%
# how to check bottom
df.tail(3)
# Out:
#    Emp_ID      Name Department  Salary  Working hours
# 5       6       ria      sales   35000              6
# 6       7    muskan         hr   30000              7
# 7       8  shivangi         hr   40000              8

# %%
# how to check random indexed data
df.sample(3)
# Out:
#    Emp_ID    Name Department  Salary  Working hours
# 4       5  anjali         it   30000              7
# 1       2   rahul         hr   30000              9
# 2       3  gaurav      sales   35000              8

# %%
# how to export data
df.to_csv("/content/sample_data/Emp_info.csv")
